# %% [markdown]
# # Fields

# %%
json_string = {
    "fields": [
        {
            "children": [],
            "dataType": "Int",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 252,
            "name": "ZPU_Przebieg",
            "symbol": "ZPU_Przebieg",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Int",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 257,
            "name": "ZPU_Rok_produkcji",
            "symbol": "ZPU_Rok_produkcji",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Int",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 318,
            "name": "ZPU_LiczbaKolizji",
            "symbol": "ZPU_LiczbaKolizji",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Int",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 325,
            "name": "ZPU_LiczbaKierowcow",
            "symbol": "ZPU_LiczbaKierowcow",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "String",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 329,
            "name": "ZPU_czyGarazowany",
            "symbol": "ZPU_czyGarazowany",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "String",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 336,
            "name": "ZPU_NumerRejestracyjny",
            "symbol": "ZPU_NumerRejestracyjny",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "String",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 244,
            "name": "ZPU_marka_pojazdu",
            "symbol": "ZPU_marka_pojazdu",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "String",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 259,
            "name": "ZPU_Typ_pojazdu",
            "symbol": "ZPU_Typ_pojazdu",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 305,
            "name": "ZPU_OC",
            "symbol": "ZPU_OC",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 308,
            "name": "ZPU_AC",
            "symbol": "ZPU_AC",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 314,
            "name": "ZPU_NNW",
            "symbol": "ZPU_NNW",
            "unitId": 25
        },
        {
            "children": [
                {
                    "maxCharacters": 20,
                    "minCharacters": 2,
                    "symbol": "ImieKlienta",
                    "type": "Default"
                },
                {
                    "maxCharacters": 20,
                    "minCharacters": 2,
                    "symbol": "NazwiskoKlienta",
                    "type": "Default"
                },
                {
                    "clientValidationId": 2,
                    "symbol": "PESELKlienta",
                    "type": "Default"
                },
                {
                    "clientValidationId": 3,
                    "symbol": "EmailKlienta",
                    "type": "Default"
                },
                {
                    "maxCharacters": 9,
                    "minCharacters": 9,
                    "symbol": "TelefonKlienta",
                    "type": "Default"
                }
            ],
            "dataType": "Domena_APD_M.obszar_AngKor.DaneOsobowe_S",
            "dataTypeComponents": [
                {
                    "name": "ImieKlienta",
                    "symbol": "ImieKlienta",
                    "type": "String"
                },
                {
                    "name": "NazwiskoKlienta",
                    "symbol": "NazwiskoKlienta",
                    "type": "String"
                },
                {
                    "name": "PESELKlienta",
                    "symbol": "PESELKlienta",
                    "type": "String"
                },
                {
                    "name": "EmailKlienta",
                    "symbol": "EmailKlienta",
                    "type": "String"
                },
                {
                    "name": "TelefonKlienta",
                    "symbol": "TelefonKlienta",
                    "type": "String"
                }
            ],
            "domainId": 5,
            "id": 606,
            "name": "ZPU_dane_osobowe",
            "symbol": "ZPU_dane_osobowe",
            "unitId": 25
        },
        {
            "children": [
                {
                    "children": [
                        {
                            "dictionaryId": 21,
                            "symbol": "Wojewodztwo",
                            "type": "Default"
                        },
                        {
                            "dictionaryId": 23,
                            "symbol": "Typ_adresu",
                            "type": "Default"
                        }
                    ],
                    "symbol": "t.",
                    "type": "Table"
                }
            ],
            "dataType": "Domena_APD_M.obszar_AngKor.DaneAdresowe_T",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 634,
            "name": "ZPU_DaneAdresowe",
            "symbol": "ZPU_DaneAdresowe",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "String",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 700,
            "name": "ZPU_RODO_komunikat",
            "symbol": "ZPU_RODO_komunikat",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 613,
            "name": "ZPU_RODO",
            "symbol": "ZPU_RODO",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 865,
            "name": "ZPU_czy_powyzej_35t",
            "symbol": "ZPU_czy_powyzej_35t",
            "unitId": 25
        },
        {
            "children": [],
            "dataType": "Bool",
            "dataTypeComponents": [],
            "domainId": 5,
            "id": 869,
            "name": "ZPU_czy_budowlany",
            "symbol": "ZPU_czy_budowlany",
            "unitId": 25
        }
    ],
    "screens": [
        {
            "id": 938,
            "name": "Ekran_1_Powitanie",
            "symbol": "Ekran_1_AngKor"
        },
        {
            "id": 935,
            "name": "Tech_TopScreen",
            "symbol": "Tech_TopScreen"
        },
        {
            "id": 936,
            "name": "Tech_BottomScreen",
            "symbol": "Tech_BottomScreen"
        },
        {
            "id": 937,
            "name": "Tech_TabsScreen",
            "symbol": "Tech_TabsScreen"
        },
        {
            "id": 939,
            "name": "Ekran_2_Zakres_ubezpieczenia",
            "symbol": "Ekran_2_AngKor"
        },
        {
            "id": 940,
            "name": "Ekran3_Dane_Osobowe",
            "symbol": "Ekran3_Ang_Kor"
        },
        {
            "id": 941,
            "name": "Ekran_4_Dane_adresowe",
            "symbol": "Ekran_4_Dane_adresowe"
        },
        {
            "id": 942,
            "name": "Ekran_5_Podsumowanie",
            "symbol": "Ekran_5_Podsumowanie"
        },
        {
            "id": 1021,
            "name": "Ekran15_TypPojazdu",
            "symbol": "Ekran15_TypPojazdu"
        },
        {
            "id": 1256,
            "name": "Ekran_65_Decyzja_Konsultanta",
            "symbol": "Ekran_65_Decyzja_Konsultanta"
        },
        {
            "id": 1252,
            "name": "Ekran_6_Podziękowanie",
            "symbol": "Ekran_6Podziekowanie"
        }
    ]
}

# %%
csharp_data_types = [
    "Byte",
    "Sbyte",
    "Short",
    "Ushort",
    "Int",
    "Uint",
    "Long",
    "Ulong",
    "Float",
    "Double",
    "Decimal",
    "Char",
    "Bool",
    "String",
    "Object",
    "Dynamic",
    "Void",
    "Nint",
    "Nuint",
    "DateTime"
]

# %%
import json
from typing import Tuple
import re

def parse_context_json(context: dict):
    # context = json.loads(context)
    
    fields = context["fields"]
    fields_processed = []
    for field in fields:
        if not field["children"]:
            fields_processed.append(f"PF.{field["symbol"]}: {field["dataType"]}")
        else:
            structure = field["dataType"].split(".")[-1]
            
            if field["children"][0]["type"] and field["children"][0]["type"] == "Table":
                for child in field["children"][0]["children"]:
                    fields_processed.append(f"PF.{structure}.{child["symbol"]}: Str")
            else:
                for component in field["dataTypeComponents"]:
                    fields_processed.append(f"PF.{structure}.{component['symbol']}: {component['type']}")
                    
    fields_processed_joined = "\n".join(fields_processed)
    
    
    return fields_processed_joined

# %%
print(parse_context_json(json_string))
# Out:
# PF.ZPU_Przebieg: Int
# PF.ZPU_Rok_produkcji: Int
# PF.ZPU_LiczbaKolizji: Int
# PF.ZPU_LiczbaKierowcow: Int
# PF.ZPU_czyGarazowany: String
# PF.ZPU_NumerRejestracyjny: String
# PF.ZPU_marka_pojazdu: String
# PF.ZPU_Typ_pojazdu: String
# PF.ZPU_OC: Bool
# PF.ZPU_AC: Bool
# PF.ZPU_NNW: Bool
# PF.DaneOsobowe_S.ImieKlienta: String
# PF.DaneOsobowe_S.NazwiskoKlienta: String
# PF.DaneOsobowe_S.PESELKlienta: String
# PF.DaneOsobowe_S.EmailKlienta: String
# PF.DaneOsobowe_S.TelefonKlienta: String
# PF.DaneAdresowe_T.Wojewodztwo: Str
# PF.DaneAdresowe_T.Typ_adresu: Str
# PF.ZPU_RODO_komunikat: String
# PF.ZPU_RODO: Bool
# PF.ZPU_czy_powyzej_35t: Bool
# PF.ZPU_czy_budowlany: Bool

# %%
presentation_str = {'fields': [{'children': [], 'dataType': 'LowCodeAI.LowCodeAI.UR_DaneKlienta_S', 'dataTypeComponents': [{'name': 'Imię', 'symbol': 'Imie', 'type': 'String'}, {'name': 'Nazwisko', 'symbol': 'Nazwisko', 'type': 'String'}, {'name': 'Email', 'symbol': 'Email', 'type': 'String'}, {'name': 'Numer telefonu', 'symbol': 'NrTelefonu', 'type': 'String'}], 'domainId': 21, 'id': 1383, 'name': 'UR_DaneKlienta_S', 'symbol': 'UR_DaneKlienta_S', 'unitId': 79}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 21, 'id': 1388, 'name': 'UR_KodZnizkowy', 'symbol': 'UR_KodZnizkowy', 'unitId': 79}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 21, 'id': 1389, 'name': 'UR_OdrzuceniePrzezWiek', 'symbol': 'UR_OdrzuceniePrzezWiek', 'unitId': 79}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 21, 'id': 1385, 'name': 'UR_RodzajUbezpieczenia', 'symbol': 'UR_RodzajUbezpieczenia', 'unitId': 79}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 21, 'id': 1390, 'name': 'UR_Skladka', 'symbol': 'UR_Skladka', 'unitId': 79}, {'children': [], 'dataType': 'LowCodeAI.LowCodeAI.UR_DaneRodziny_T', 'dataTypeComponents': [], 'domainId': 21, 'id': 1384, 'name': 'UR_DaneRodziny_T', 'symbol': 'UR_DaneRodziny_T', 'unitId': 79}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 21, 'id': 1391, 'name': 'tech_Message', 'symbol': 'tech_Message', 'unitId': 79}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 21, 'id': 1387, 'name': 'UR_PoziomUbezpieczenia', 'symbol': 'UR_PoziomUbezpieczenia', 'unitId': 79}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 21, 'id': 1386, 'name': 'UR_UbezpieczenieDodatkowe', 'symbol': 'UR_UbezpieczenieDodatkowe', 'unitId': 79}], 'screens': [{'id': 1749, 'name': 'Tech_BottomScreen', 'symbol': 'Tech_BottomScreen'}, {'id': 1750, 'name': 'Tech_TopScreen', 'symbol': 'Tech_TopScreen'}, {'id': 1751, 'name': 'Tech_TabsScreen', 'symbol': 'Tech_TabsScreen'}, {'id': 1752, 'name': 'Tech_SessionEndScreen', 'symbol': 'Tech_SessionEndScreen'}, {'id': 1756, 'name': 'Zgody', 'symbol': 'E040_Zgody'}, {'id': 1754, 'name': 'Dane rodziny', 'symbol': 'E020_DaneRodziny'}, {'id': 1757, 'name': 'Podsumowanie', 'symbol': 'E050_Podsumowanie'}, {'id': 1755, 'name': 'Wybór ubezpieczenia', 'symbol': 'E030_WyborUbezpieczenia'}, {'id': 1753, 'name': 'Powitanie', 'symbol': 'E010_Powitanie'}, {'id': 1758, 'name': 'Odrzucenie', 'symbol': 'E060_Odrzucenie'}, {'id': 1759, 'name': 'E_techMessage', 'symbol': 'E_techMessage'}], 'tasks': [{'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'Ugk7uvCAqE6', 'name': 'InitialEvent0', 'relations': [{'id': 'arrow_rS9mmDmOK', 'targetId': 'UOVxuqQ5Fyv', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowInitialEvent'}, {'actionsList': [{'actionId': 'nhgsEfqF95n', 'actionType': 'StateIn', 'name': 'InUserTask0', 'symbol': 'InUserTask0'}, {'actionId': 'iyzxYmuxN4i', 'actionType': 'StateOut', 'name': 'OutUserTask0', 'symbol': 'OutUserTask0'}, {'actionId': 'NuO4oLfkKJ', 'actionType': 'Standard', 'name': 'a010_nextTask', 'symbol': 'a010_nextTask'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'UOVxuqQ5Fyv', 'name': 'ut010_Powitanie', 'relations': [{'id': 'arrow_lsxjLzbIb', 'targetId': 'lQVAoAT3l2', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'YQvgMTa6WA', 'actionType': 'StateIn', 'name': 'InUserTask0_0', 'symbol': 'InUserTask0_0'}, {'actionId': 'kmycp5fOoh', 'actionType': 'StateOut', 'name': 'OutUserTask0_0', 'symbol': 'OutUserTask0_0'}, {'actionId': 'OnAJ725Xa', 'actionType': 'Standard', 'name': 'a020_calculateRisk', 'symbol': 'a020_calculateRisk'}, {'actionId': 'lBMUADenIm', 'actionType': 'Standard', 'name': 'a020_nextTask', 'symbol': 'a020_nextTask'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'lQVAoAT3l2', 'name': 'ut020_DaneRodziny', 'relations': [{'id': 'arrow_AOzFCWmA1', 'targetId': 'iCKdg2MRVkA', 'type': 'Arrow'}, {'id': 'arrow_zTACeYl5k', 'targetId': 'AU21puu7Xk', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'HG0suH57msL', 'actionType': 'StateIn', 'name': 'InUserTask0_1', 'symbol': 'InUserTask0_1'}, {'actionId': 'zUV6uqXFq', 'actionType': 'Standard', 'name': 'a030_calculateFee', 'symbol': 'a030_calculateFee'}, {'actionId': 'DayCh3AKizF', 'actionType': 'StateOut', 'name': 'OutUserTask0_1', 'symbol': 'OutUserTask0_1'}, {'actionId': 'OhERXDJ0km', 'actionType': 'Standard', 'name': 'ChangeState_ut030_WyborUbezpieczenia_UserTask0', 'symbol': 'a030_nextStatus'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'iCKdg2MRVkA', 'name': 'ut030_WyborUbezpieczenia', 'relations': [{'id': 'arrow_iPQlyrajX', 'targetId': 'jWZQFSuFck3', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '4R06QkImp1', 'actionType': 'StateIn', 'name': 'InUserTask0_2', 'symbol': 'InUserTask0_2'}, {'actionId': '0ypDFSXihe', 'actionType': 'StateOut', 'name': 'OutUserTask0_2', 'symbol': 'OutUserTask0_2'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'AU21puu7Xk', 'name': 'ut025_Odrzucenie', 'relations': [], 'screenConfiguration': [], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'TyVlLScGCjK', 'actionType': 'StateIn', 'name': 'InUserTask0_3', 'symbol': 'InUserTask0_3'}, {'actionId': '9bftC4RVU', 'actionType': 'Standard', 'name': 'a040_validateDiscountCode', 'symbol': 'a040_validateDiscountCode'}, {'actionId': 'ms8dgNgGJPz', 'actionType': 'StateOut', 'name': 'OutUserTask0_3', 'symbol': 'OutUserTask0_3'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'jWZQFSuFck3', 'name': 'ut040_KodRabatowy', 'relations': [], 'screenConfiguration': [], 'type': 'FlowUserTask'}], 'location': 'https://uamedu.domdata.com/architect/bpmnDesigner'}

# %%
print(parse_context_json(presentation_str))
# Out:
# PF.UR_DaneKlienta_S: LowCodeAI.LowCodeAI.UR_DaneKlienta_S
# PF.UR_KodZnizkowy: String
# PF.UR_OdrzuceniePrzezWiek: Bool
# PF.UR_RodzajUbezpieczenia: String
# PF.UR_Skladka: Decimal
# PF.UR_DaneRodziny_T: LowCodeAI.LowCodeAI.UR_DaneRodziny_T
# PF.tech_Message: String
# PF.UR_PoziomUbezpieczenia: String
# PF.UR_UbezpieczenieDodatkowe: Bool

# %% [markdown]
# We can't depend on children.type field because it may be empty like above.

# %%
def parse_context_json_v2(context: dict):
    """Approach 2: Using hardcoded data types.
        Assumptions (may need corrections):
        - if dataType is a predefined dataType, it is a simple datatype (str,int,etc)
        - if dataType is not simple and children are empty and dataTypeComponents exist, it is a structure
        - if dataType is not simple and children are empty and dataTypeComponents dont exist, it is a table (without fields)
        - if dataType is not simple and children exist and dataTypeComponents exist, it is a structure
        - if dataType is not simple and children exist and dataTypeComponents dont exist, it is a table (with defined fields)
        - structure always have non-empty dataTypeComponents
    """
    fields_processed = []
    try:
        fields = context["fields"]
        for field in fields:
            if field["dataType"] in csharp_data_types:
                fields_processed.append(f"PF.{field["symbol"]}: {field["dataType"]}")
            else:
                structure = field["dataType"].split(".")[-1]
                if not field["children"]:
                    if field["dataTypeComponents"]:
                        for component in field["dataTypeComponents"]:
                            fields_processed.append(f"PF.{structure}.{component['symbol']}: {component['type']}")
                    else:
                            fields_processed.append(f"PF.{structure}: Table")
                else:
                    if field["dataTypeComponents"]:
                        for component in field["dataTypeComponents"]:
                            fields_processed.append(f"PF.{structure}.{component['symbol']}: {component['type']}")
                    else:
                        fields_processed.append(f"PF.{structure}: Table")
                        for child in field["children"][0]["children"]:
                            fields_processed.append(f"  {child["symbol"]}: Str")
    except Exception as e:
        fields_processed.append(f"Data model not available due to error: {str(e)}. Ask user to provide data model.")
                    
    fields_processed_joined = "\n".join(fields_processed)
    
    
    return fields_processed_joined

# %%
print(parse_context_json_v2(presentation_str))
# Out:
# PF.UR_DaneKlienta_S.Imie: String
# PF.UR_DaneKlienta_S.Nazwisko: String
# PF.UR_DaneKlienta_S.Email: String
# PF.UR_DaneKlienta_S.NrTelefonu: String
# PF.UR_KodZnizkowy: String
# PF.UR_OdrzuceniePrzezWiek: Bool
# PF.UR_RodzajUbezpieczenia: String
# PF.UR_Skladka: Decimal
# PF.UR_DaneRodziny_T: Table
# PF.tech_Message: String
# PF.UR_PoziomUbezpieczenia: String
# PF.UR_UbezpieczenieDodatkowe: Bool

# %%
print(parse_context_json_v2(json_string))
# Out:
# PF.ZPU_Przebieg: Int
# PF.ZPU_Rok_produkcji: Int
# PF.ZPU_LiczbaKolizji: Int
# PF.ZPU_LiczbaKierowcow: Int
# PF.ZPU_czyGarazowany: String
# PF.ZPU_NumerRejestracyjny: String
# PF.ZPU_marka_pojazdu: String
# PF.ZPU_Typ_pojazdu: String
# PF.ZPU_OC: Bool
# PF.ZPU_AC: Bool
# PF.ZPU_NNW: Bool
# PF.DaneOsobowe_S.ImieKlienta: String
# PF.DaneOsobowe_S.NazwiskoKlienta: String
# PF.DaneOsobowe_S.PESELKlienta: String
# PF.DaneOsobowe_S.EmailKlienta: String
# PF.DaneOsobowe_S.TelefonKlienta: String
# PF.DaneAdresowe_T: Table
#   Wojewodztwo: Str
#   Typ_adresu: Str
# PF.ZPU_RODO_komunikat: String
# PF.ZPU_RODO: Bool
# PF.ZPU_czy_powyzej_35t: Bool
# PF.ZPU_czy_budowlany: Bool

# %%
json_dict = {'fields': [{'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1215, 'name': 'Kredyt_RODO_komunikat', 'symbol': 'Kredyt_RODO_komunikat', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1218, 'name': 'Kredyt_zgody_koncowe', 'symbol': 'Kredyt_zgody_koncowe', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 949, 'name': 'Kredyt_Imie_Klienta', 'symbol': 'Kredyt_Imie_Klienta', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 950, 'name': 'Kredyt_Nazwisko', 'symbol': 'Kredyt_Nazwisko', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 951, 'name': 'Kredyt_waznosc_dowodu', 'symbol': 'Kredyt_waznosc_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 952, 'name': 'Kredyt_nr_dowodu', 'symbol': 'Kredyt_nr_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 953, 'name': 'Kredyt_Pesel', 'symbol': 'Kredyt_Pesel', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 955, 'name': 'Kredyt_e_mail', 'symbol': 'Kredyt_e_mail', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 956, 'name': 'Kredyt_Data_urodzenia', 'symbol': 'Kredyt_Data_urodzenia', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 957, 'name': 'Kredyt_data_wydania_dowodu', 'symbol': 'Kredyt_data_wydania_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 958, 'name': 'Kredyt_RODO', 'symbol': 'Kredyt_RODO', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 959, 'name': 'Kredyt_Komunikat_RODO', 'symbol': 'Kredyt_Komunikat_RODO', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1014, 'name': 'Kredyt_wynagrodzenie_za_prace', 'symbol': 'Kredyt_wynagrodzenie_za_prace', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1015, 'name': 'Kredyt_branza', 'symbol': 'Kredyt_branza', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1016, 'name': 'Kredyt_zawod', 'symbol': 'Kredyt_zawod', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1020, 'name': 'Kredyt_czym_zajmuje_sie_firma', 'symbol': 'Kredyt_czym_zajmuje_sie_firma', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1193, 'name': 'Kredyt_bilans_finansowy', 'symbol': 'Kredyt_bilans_finansowy', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1021, 'name': 'Kredyt_emerytura_renta', 'symbol': 'Kredyt_emerytura_renta', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1022, 'name': 'Kredyt_dochod_malzonka', 'symbol': 'Kredyt_dochod_malzonka', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1194, 'name': 'Kredyt_dochod_wynagrodzenie', 'symbol': 'Kredyt_dochod_wynagrodzenie', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1023, 'name': 'Kredyt_alimenty', 'symbol': 'Kredyt_alimenty', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1195, 'name': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'symbol': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1048, 'name': 'Kredyt_Info_Admi', 'symbol': 'Kredyt_Info_Admi', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1050, 'name': 'Kredyt_marketing_tel', 'symbol': 'Kredyt_marketing_tel', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1053, 'name': 'Kredyt_data_waznosci', 'symbol': 'Kredyt_data_waznosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1024, 'name': 'Kredyt_zasilki_spoleczne_socjalne', 'symbol': 'Kredyt_zasilki_spoleczne_socjalne', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1025, 'name': 'Kredyt_pozyczka', 'symbol': 'Kredyt_pozyczka', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1049, 'name': 'Kredyt_reg_drog_elektroniczna', 'symbol': 'Kredyt_reg_drog_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1054, 'name': 'Kredyt_datawydania', 'symbol': 'Kredyt_datawydania', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1196, 'name': 'Kredyt_dochod_malzonk', 'symbol': 'Kredyt_dochod_malzonk', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1026, 'name': 'Kredyt_inne', 'symbol': 'Kredyt_inne', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1197, 'name': 'Kredyt_dochod_emerytura', 'symbol': 'Kredyt_dochod_emerytura', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1198, 'name': 'Kredyt_dochod_zasilek', 'symbol': 'Kredyt_dochod_zasilek', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1029, 'name': 'Kredyt_wysokosc_kredytu', 'symbol': 'Kredyt_wysokosc_kredytu', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1030, 'name': 'Kredyt_dochod', 'symbol': 'Kredyt_dochod', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 954, 'name': 'Kredyt_nr_telefonu', 'symbol': 'Kredyt_nr_telefonu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1032, 'name': 'Kredyt_zgodnosc_informacji', 'symbol': 'Kredyt_zgodnosc_informacji', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1033, 'name': 'Kredyt_regulamin', 'symbol': 'Kredyt_regulamin', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1034, 'name': 'Kredyt_odpowiedzialnosc_karna', 'symbol': 'Kredyt_odpowiedzialnosc_karna', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1098, 'name': 'Kredyt_wysokosc_pozyczki', 'symbol': 'Kredyt_wysokosc_pozyczki', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1099, 'name': 'Kredyt_ilosc_rat', 'symbol': 'Kredyt_ilosc_rat', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1017, 'name': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'symbol': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1018, 'name': 'Kredyt_nazwa_firmy', 'symbol': 'Kredyt_nazwa_firmy', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1019, 'name': 'Kredyt_NIP_REGON', 'symbol': 'Kredyt_NIP_REGON', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1027, 'name': 'Kredyt_inne_string', 'symbol': 'Kredyt_inne_string', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1028, 'name': 'Kredyt_nazwa_banku', 'symbol': 'Kredyt_nazwa_banku', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1051, 'name': 'Kredyt_marketnig_elektroniczna', 'symbol': 'Kredyt_marketnig_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1031, 'name': 'Kredyt_rodzaj_zasilku', 'symbol': 'Kredyt_rodzaj_zasilku', 'unitId': 58}], 'screens': [{'id': 1536, 'name': 'Ekran_5_Zrodla_dochodow', 'symbol': 'Ekran_5_Zrodla_dochodow'}, {'id': 1534, 'name': 'Ekran_2_Dane_osobowe', 'symbol': 'Ekran_2_Dane_osobowe'}, {'id': 1537, 'name': 'Ekran_6_Podziekowanie', 'symbol': 'Ekran_6_Podziekowanie'}, {'id': 1539, 'name': 'Tech_BottomScreen', 'symbol': 'Tech_BottomScreen'}, {'id': 1540, 'name': 'Tech_TabsScreen', 'symbol': 'Tech_TabsScreen'}, {'id': 1541, 'name': 'Tech_TopScreen', 'symbol': 'Tech_TopScreen'}, {'id': 1535, 'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'symbol': 'Ekran_3_zrodla_wysokosc_dochodow'}, {'id': 1538, 'name': 'Ekran_65_Decyzja_konsultanta', 'symbol': 'Ekran_65_Decyzja_konsultanta'}, {'id': 1533, 'name': 'Ekran_1_ekran_Startowy', 'symbol': 'Ekran_1_ekran_Startowy'}], 'tasks': [{'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'sqif0GojUKI', 'name': 'InitialEvent0', 'relations': [{'id': 'arrow_mUsp4nJXu', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowInitialEvent'}, {'actionsList': [{'actionId': '2N8KxRhMBg2', 'actionType': 'StateIn', 'name': 'InUserTask0', 'symbol': 'InUserTask0'}, {'actionId': 'fZcUQQFoWId', 'actionType': 'StateOut', 'name': 'OutUserTask0', 'symbol': 'OutUserTask0'}, {'actionId': 'ejXwc6mkJN', 'actionType': 'Standard', 'name': 'a010_zoz_wniosek_online', 'symbol': 'a010_zoz_wniosek_online'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'A92RfIeeD1H', 'name': 'ut010_Startowy', 'relations': [{'id': 'arrow_tAzCWAAES', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': True}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '3HnTqJga3Hp', 'actionType': 'StateIn', 'name': 'InUserTask0_0', 'symbol': 'InUserTask0_0'}, {'actionId': 'HfMZAvsAUNp', 'actionType': 'StateOut', 'name': 'OutUserTask0_0', 'symbol': 'OutUserTask0_0'}, {'actionId': 'dIETSsy8l5', 'actionType': 'Standard', 'name': 'a020_Wstecz', 'symbol': 'a020_Wstecz'}, {'actionId': '72lLoVteTv', 'actionType': 'Standard', 'name': 'a020_dalej', 'symbol': 'a020_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'qcWPy4tnq2D', 'name': 'ut_020_dane_wnioskodawcy', 'relations': [{'id': 'arrow_suZAGAEA2', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}, {'id': 'arrow_nXLqve8W2', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}, {'id': 'arrow_lSglFqJe2', 'targetId': None, 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': True}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'QGjAWamgD2X', 'actionType': 'StateIn', 'name': 'InUserTask0_1', 'symbol': 'InUserTask0_1'}, {'actionId': 'zT40C4LdjOU', 'actionType': 'StateOut', 'name': 'OutUserTask0_1', 'symbol': 'OutUserTask0_1'}, {'actionId': 'RAOR4dDMMk', 'actionType': 'Standard', 'name': 'a030_wstecz', 'symbol': 'a030_wstecz'}, {'actionId': 'i1dWMSlwsk', 'actionType': 'Standard', 'name': 'a030_dalej', 'symbol': 'a030_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'nlNJf9NHp6g', 'name': 'ut030_parametry_pozyczki', 'relations': [{'id': 'arrow_7uBa0srSU', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}, {'id': 'arrow_AjiPAlS3s', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_kxEkdmBae', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_aGADHKzzZ', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': True}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '5wAt6CQ8fVq', 'actionType': 'StateIn', 'name': 'InUserTask0_3', 'symbol': 'InUserTask0_3'}, {'actionId': 'm1Rxxtf0KmN', 'actionType': 'StateOut', 'name': 'OutUserTask0_3', 'symbol': 'OutUserTask0_3'}, {'actionId': 'rrLBc2Na8b', 'actionType': 'Standard', 'name': 'a050_WyslijDoWeryfikacji', 'symbol': 'a050_WyslijDoWeryfikacji'}, {'actionId': 'iKXc6zh65G', 'actionType': 'Standard', 'name': 'a050_wstecz', 'symbol': 'a050_wstecz'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'Ec8tA2KQFEB', 'name': 'ut050_Zrodla_dochodow', 'relations': [{'id': 'arrow_zuREiTB7Z', 'targetId': 'D9AjaaZA8gg', 'type': 'Arrow'}, {'id': 'arrow_AnCASNgkH', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': True}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'Qb5Fr2OTEBl', 'actionType': 'StateIn', 'name': 'InUserTask0_4', 'symbol': 'InUserTask0_4'}, {'actionId': 'I4EH9EdmEej', 'actionType': 'StateOut', 'name': 'OutUserTask0_4', 'symbol': 'OutUserTask0_4'}, {'actionId': 'De1AOtYCJo', 'actionType': 'Standard', 'name': 'Zaakceptuj', 'symbol': 'a060_Akceptacja'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'D9AjaaZA8gg', 'name': 'ut060_decyzja_konsultanta', 'relations': [{'id': 'arrow_tz3xv7yhA', 'targetId': 'pxzdcS8iM03', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': True}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': True}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': True}], 'type': 'FlowUserTask'}, {'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'pxzdcS8iM03', 'name': 'ee060_akceptacjaWnioskuKredyt', 'relations': [], 'screenConfiguration': [], 'type': 'FlowEndEvent'}], 'location': 'https://uamedu.domdata.com/architect/bpmnDesigner'}

# %%
print(parse_context_json_v2(json_dict))
# Out:
# PF.Kredyt_RODO_komunikat: String
# PF.Kredyt_zgody_koncowe: String
# PF.Kredyt_Imie_Klienta: String
# PF.Kredyt_Nazwisko: String
# PF.Kredyt_waznosc_dowodu: String
# PF.Kredyt_nr_dowodu: String
# PF.Kredyt_Pesel: String
# PF.Kredyt_e_mail: String
# PF.Kredyt_Data_urodzenia: String
# PF.Kredyt_data_wydania_dowodu: String
# PF.Kredyt_RODO: Bool
# PF.Kredyt_Komunikat_RODO: String
# PF.Kredyt_wynagrodzenie_za_prace: Bool
# PF.Kredyt_branza: String
# PF.Kredyt_zawod: String
# PF.Kredyt_czym_zajmuje_sie_firma: String
# PF.Kredyt_bilans_finansowy: Int
# PF.Kredyt_emerytura_renta: Bool
# PF.Kredyt_dochod_malzonka: Bool
# PF.Kredyt_dochod_wynagrodzenie: Decimal
# PF.Kredyt_alimenty: Bool
# PF.Kredyt_dochod_prowadzenie_dzialalnosci: Decimal
# PF.Kredyt_Info_Admi: Bool
# PF.Kredyt_marketing_tel: Bool
# PF.Kredyt_data_waznosci: DateTime
# PF.Kredyt_zasilki_spoleczne_socjalne: Bool
# PF.Kredyt_pozyczka: Bool
# PF.Kredyt_reg_drog_elektroniczna: Bool
# PF.Kredyt_datawydania: DateTime
# ...

# %%
dict3 = {'fields': [{'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1215, 'name': 'Kredyt_RODO_komunikat', 'symbol': 'Kredyt_RODO_komunikat', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1218, 'name': 'Kredyt_zgody_koncowe', 'symbol': 'Kredyt_zgody_koncowe', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 949, 'name': 'Kredyt_Imie_Klienta', 'symbol': 'Kredyt_Imie_Klienta', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 950, 'name': 'Kredyt_Nazwisko', 'symbol': 'Kredyt_Nazwisko', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 951, 'name': 'Kredyt_waznosc_dowodu', 'symbol': 'Kredyt_waznosc_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 952, 'name': 'Kredyt_nr_dowodu', 'symbol': 'Kredyt_nr_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 953, 'name': 'Kredyt_Pesel', 'symbol': 'Kredyt_Pesel', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 955, 'name': 'Kredyt_e_mail', 'symbol': 'Kredyt_e_mail', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 956, 'name': 'Kredyt_Data_urodzenia', 'symbol': 'Kredyt_Data_urodzenia', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 957, 'name': 'Kredyt_data_wydania_dowodu', 'symbol': 'Kredyt_data_wydania_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 958, 'name': 'Kredyt_RODO', 'symbol': 'Kredyt_RODO', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 959, 'name': 'Kredyt_Komunikat_RODO', 'symbol': 'Kredyt_Komunikat_RODO', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1014, 'name': 'Kredyt_wynagrodzenie_za_prace', 'symbol': 'Kredyt_wynagrodzenie_za_prace', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1015, 'name': 'Kredyt_branza', 'symbol': 'Kredyt_branza', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1016, 'name': 'Kredyt_zawod', 'symbol': 'Kredyt_zawod', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1020, 'name': 'Kredyt_czym_zajmuje_sie_firma', 'symbol': 'Kredyt_czym_zajmuje_sie_firma', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1193, 'name': 'Kredyt_bilans_finansowy', 'symbol': 'Kredyt_bilans_finansowy', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1021, 'name': 'Kredyt_emerytura_renta', 'symbol': 'Kredyt_emerytura_renta', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1022, 'name': 'Kredyt_dochod_malzonka', 'symbol': 'Kredyt_dochod_malzonka', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1194, 'name': 'Kredyt_dochod_wynagrodzenie', 'symbol': 'Kredyt_dochod_wynagrodzenie', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1023, 'name': 'Kredyt_alimenty', 'symbol': 'Kredyt_alimenty', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1195, 'name': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'symbol': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1048, 'name': 'Kredyt_Info_Admi', 'symbol': 'Kredyt_Info_Admi', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1050, 'name': 'Kredyt_marketing_tel', 'symbol': 'Kredyt_marketing_tel', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1053, 'name': 'Kredyt_data_waznosci', 'symbol': 'Kredyt_data_waznosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1024, 'name': 'Kredyt_zasilki_spoleczne_socjalne', 'symbol': 'Kredyt_zasilki_spoleczne_socjalne', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1025, 'name': 'Kredyt_pozyczka', 'symbol': 'Kredyt_pozyczka', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1049, 'name': 'Kredyt_reg_drog_elektroniczna', 'symbol': 'Kredyt_reg_drog_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1054, 'name': 'Kredyt_datawydania', 'symbol': 'Kredyt_datawydania', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1196, 'name': 'Kredyt_dochod_malzonk', 'symbol': 'Kredyt_dochod_malzonk', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1026, 'name': 'Kredyt_inne', 'symbol': 'Kredyt_inne', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1197, 'name': 'Kredyt_dochod_emerytura', 'symbol': 'Kredyt_dochod_emerytura', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1198, 'name': 'Kredyt_dochod_zasilek', 'symbol': 'Kredyt_dochod_zasilek', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1029, 'name': 'Kredyt_wysokosc_kredytu', 'symbol': 'Kredyt_wysokosc_kredytu', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1030, 'name': 'Kredyt_dochod', 'symbol': 'Kredyt_dochod', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 954, 'name': 'Kredyt_nr_telefonu', 'symbol': 'Kredyt_nr_telefonu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1032, 'name': 'Kredyt_zgodnosc_informacji', 'symbol': 'Kredyt_zgodnosc_informacji', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1033, 'name': 'Kredyt_regulamin', 'symbol': 'Kredyt_regulamin', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1034, 'name': 'Kredyt_odpowiedzialnosc_karna', 'symbol': 'Kredyt_odpowiedzialnosc_karna', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1098, 'name': 'Kredyt_wysokosc_pozyczki', 'symbol': 'Kredyt_wysokosc_pozyczki', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1099, 'name': 'Kredyt_ilosc_rat', 'symbol': 'Kredyt_ilosc_rat', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1017, 'name': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'symbol': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1018, 'name': 'Kredyt_nazwa_firmy', 'symbol': 'Kredyt_nazwa_firmy', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1019, 'name': 'Kredyt_NIP_REGON', 'symbol': 'Kredyt_NIP_REGON', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1027, 'name': 'Kredyt_inne_string', 'symbol': 'Kredyt_inne_string', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1028, 'name': 'Kredyt_nazwa_banku', 'symbol': 'Kredyt_nazwa_banku', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1051, 'name': 'Kredyt_marketnig_elektroniczna', 'symbol': 'Kredyt_marketnig_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1031, 'name': 'Kredyt_rodzaj_zasilku', 'symbol': 'Kredyt_rodzaj_zasilku', 'unitId': 58}], 'screens': [{'id': 1536, 'name': 'Ekran_5_Zrodla_dochodow', 'symbol': 'Ekran_5_Zrodla_dochodow'}, {'id': 1534, 'name': 'Ekran_2_Dane_osobowe', 'symbol': 'Ekran_2_Dane_osobowe'}, {'id': 1537, 'name': 'Ekran_6_Podziekowanie', 'symbol': 'Ekran_6_Podziekowanie'}, {'id': 1539, 'name': 'Tech_BottomScreen', 'symbol': 'Tech_BottomScreen'}, {'id': 1540, 'name': 'Tech_TabsScreen', 'symbol': 'Tech_TabsScreen'}, {'id': 1541, 'name': 'Tech_TopScreen', 'symbol': 'Tech_TopScreen'}, {'id': 1535, 'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'symbol': 'Ekran_3_zrodla_wysokosc_dochodow'}, {'id': 1538, 'name': 'Ekran_65_Decyzja_konsultanta', 'symbol': 'Ekran_65_Decyzja_konsultanta'}, {'id': 1533, 'name': 'Ekran_1_ekran_Startowy', 'symbol': 'Ekran_1_ekran_Startowy'}], 'tasks': [{'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'sqif0GojUKI', 'name': 'InitialEvent0', 'relations': [{'id': 'arrow_mUsp4nJXu', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowInitialEvent'}, {'actionsList': [{'actionId': '2N8KxRhMBg2', 'actionType': 'StateIn', 'name': 'InUserTask0', 'symbol': 'InUserTask0'}, {'actionId': 'fZcUQQFoWId', 'actionType': 'StateOut', 'name': 'OutUserTask0', 'symbol': 'OutUserTask0'}, {'actionId': 'ejXwc6mkJN', 'actionType': 'Standard', 'name': 'a010_zoz_wniosek_online', 'symbol': 'a010_zoz_wniosek_online'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'A92RfIeeD1H', 'name': 'ut010_Startowy', 'relations': [{'id': 'arrow_tAzCWAAES', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': True}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '3HnTqJga3Hp', 'actionType': 'StateIn', 'name': 'InUserTask0_0', 'symbol': 'InUserTask0_0'}, {'actionId': 'HfMZAvsAUNp', 'actionType': 'StateOut', 'name': 'OutUserTask0_0', 'symbol': 'OutUserTask0_0'}, {'actionId': 'dIETSsy8l5', 'actionType': 'Standard', 'name': 'a020_Wstecz', 'symbol': 'a020_Wstecz'}, {'actionId': '72lLoVteTv', 'actionType': 'Standard', 'name': 'a020_dalej', 'symbol': 'a020_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'qcWPy4tnq2D', 'name': 'ut_020_dane_wnioskodawcy', 'relations': [{'id': 'arrow_suZAGAEA2', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}, {'id': 'arrow_nXLqve8W2', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}, {'id': 'arrow_lSglFqJe2', 'targetId': None, 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': True}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'QGjAWamgD2X', 'actionType': 'StateIn', 'name': 'InUserTask0_1', 'symbol': 'InUserTask0_1'}, {'actionId': 'zT40C4LdjOU', 'actionType': 'StateOut', 'name': 'OutUserTask0_1', 'symbol': 'OutUserTask0_1'}, {'actionId': 'RAOR4dDMMk', 'actionType': 'Standard', 'name': 'a030_wstecz', 'symbol': 'a030_wstecz'}, {'actionId': 'i1dWMSlwsk', 'actionType': 'Standard', 'name': 'a030_dalej', 'symbol': 'a030_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'nlNJf9NHp6g', 'name': 'ut030_parametry_pozyczki', 'relations': [{'id': 'arrow_7uBa0srSU', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}, {'id': 'arrow_AjiPAlS3s', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_kxEkdmBae', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_aGADHKzzZ', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': True}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '5wAt6CQ8fVq', 'actionType': 'StateIn', 'name': 'InUserTask0_3', 'symbol': 'InUserTask0_3'}, {'actionId': 'm1Rxxtf0KmN', 'actionType': 'StateOut', 'name': 'OutUserTask0_3', 'symbol': 'OutUserTask0_3'}, {'actionId': 'rrLBc2Na8b', 'actionType': 'Standard', 'name': 'a050_WyslijDoWeryfikacji', 'symbol': 'a050_WyslijDoWeryfikacji'}, {'actionId': 'iKXc6zh65G', 'actionType': 'Standard', 'name': 'a050_wstecz', 'symbol': 'a050_wstecz'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'Ec8tA2KQFEB', 'name': 'ut050_Zrodla_dochodow', 'relations': [{'id': 'arrow_zuREiTB7Z', 'targetId': 'D9AjaaZA8gg', 'type': 'Arrow'}, {'id': 'arrow_AnCASNgkH', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': True}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'Qb5Fr2OTEBl', 'actionType': 'StateIn', 'name': 'InUserTask0_4', 'symbol': 'InUserTask0_4'}, {'actionId': 'I4EH9EdmEej', 'actionType': 'StateOut', 'name': 'OutUserTask0_4', 'symbol': 'OutUserTask0_4'}, {'actionId': 'De1AOtYCJo', 'actionType': 'Standard', 'name': 'Zaakceptuj', 'symbol': 'a060_Akceptacja'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'D9AjaaZA8gg', 'name': 'ut060_decyzja_konsultanta', 'relations': [{'id': 'arrow_tz3xv7yhA', 'targetId': 'pxzdcS8iM03', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': True}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': True}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': True}], 'type': 'FlowUserTask'}, {'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'pxzdcS8iM03', 'name': 'ee060_akceptacjaWnioskuKredyt', 'relations': [], 'screenConfiguration': [], 'type': 'FlowEndEvent'}], 'location': 'https://uamedu.domdata.com/architect/bpmnDesigner'}

# %%
print(parse_context_json_v2(dict3))
# Out:
# PF.Kredyt_RODO_komunikat: String
# PF.Kredyt_zgody_koncowe: String
# PF.Kredyt_Imie_Klienta: String
# PF.Kredyt_Nazwisko: String
# PF.Kredyt_waznosc_dowodu: String
# PF.Kredyt_nr_dowodu: String
# PF.Kredyt_Pesel: String
# PF.Kredyt_e_mail: String
# PF.Kredyt_Data_urodzenia: String
# PF.Kredyt_data_wydania_dowodu: String
# PF.Kredyt_RODO: Bool
# PF.Kredyt_Komunikat_RODO: String
# PF.Kredyt_wynagrodzenie_za_prace: Bool
# PF.Kredyt_branza: String
# PF.Kredyt_zawod: String
# PF.Kredyt_czym_zajmuje_sie_firma: String
# PF.Kredyt_bilans_finansowy: Int
# PF.Kredyt_emerytura_renta: Bool
# PF.Kredyt_dochod_malzonka: Bool
# PF.Kredyt_dochod_wynagrodzenie: Decimal
# PF.Kredyt_alimenty: Bool
# PF.Kredyt_dochod_prowadzenie_dzialalnosci: Decimal
# PF.Kredyt_Info_Admi: Bool
# PF.Kredyt_marketing_tel: Bool
# PF.Kredyt_data_waznosci: DateTime
# PF.Kredyt_zasilki_spoleczne_socjalne: Bool
# PF.Kredyt_pozyczka: Bool
# PF.Kredyt_reg_drog_elektroniczna: Bool
# PF.Kredyt_datawydania: DateTime
# ...

# %%
dict4 = {'fields': [{'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1215, 'name': 'Kredyt_RODO_komunikat', 'symbol': 'Kredyt_RODO_komunikat', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1218, 'name': 'Kredyt_zgody_koncowe', 'symbol': 'Kredyt_zgody_koncowe', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 949, 'name': 'Kredyt_Imie_Klienta', 'symbol': 'Kredyt_Imie_Klienta', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 950, 'name': 'Kredyt_Nazwisko', 'symbol': 'Kredyt_Nazwisko', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 951, 'name': 'Kredyt_waznosc_dowodu', 'symbol': 'Kredyt_waznosc_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 952, 'name': 'Kredyt_nr_dowodu', 'symbol': 'Kredyt_nr_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 953, 'name': 'Kredyt_Pesel', 'symbol': 'Kredyt_Pesel', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 955, 'name': 'Kredyt_e_mail', 'symbol': 'Kredyt_e_mail', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 956, 'name': 'Kredyt_Data_urodzenia', 'symbol': 'Kredyt_Data_urodzenia', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 957, 'name': 'Kredyt_data_wydania_dowodu', 'symbol': 'Kredyt_data_wydania_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 958, 'name': 'Kredyt_RODO', 'symbol': 'Kredyt_RODO', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 959, 'name': 'Kredyt_Komunikat_RODO', 'symbol': 'Kredyt_Komunikat_RODO', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1014, 'name': 'Kredyt_wynagrodzenie_za_prace', 'symbol': 'Kredyt_wynagrodzenie_za_prace', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1015, 'name': 'Kredyt_branza', 'symbol': 'Kredyt_branza', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1016, 'name': 'Kredyt_zawod', 'symbol': 'Kredyt_zawod', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1020, 'name': 'Kredyt_czym_zajmuje_sie_firma', 'symbol': 'Kredyt_czym_zajmuje_sie_firma', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1193, 'name': 'Kredyt_bilans_finansowy', 'symbol': 'Kredyt_bilans_finansowy', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1021, 'name': 'Kredyt_emerytura_renta', 'symbol': 'Kredyt_emerytura_renta', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1022, 'name': 'Kredyt_dochod_malzonka', 'symbol': 'Kredyt_dochod_malzonka', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1194, 'name': 'Kredyt_dochod_wynagrodzenie', 'symbol': 'Kredyt_dochod_wynagrodzenie', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1023, 'name': 'Kredyt_alimenty', 'symbol': 'Kredyt_alimenty', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1195, 'name': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'symbol': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1048, 'name': 'Kredyt_Info_Admi', 'symbol': 'Kredyt_Info_Admi', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1050, 'name': 'Kredyt_marketing_tel', 'symbol': 'Kredyt_marketing_tel', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1053, 'name': 'Kredyt_data_waznosci', 'symbol': 'Kredyt_data_waznosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1024, 'name': 'Kredyt_zasilki_spoleczne_socjalne', 'symbol': 'Kredyt_zasilki_spoleczne_socjalne', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1025, 'name': 'Kredyt_pozyczka', 'symbol': 'Kredyt_pozyczka', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1049, 'name': 'Kredyt_reg_drog_elektroniczna', 'symbol': 'Kredyt_reg_drog_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1054, 'name': 'Kredyt_datawydania', 'symbol': 'Kredyt_datawydania', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1196, 'name': 'Kredyt_dochod_malzonk', 'symbol': 'Kredyt_dochod_malzonk', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1026, 'name': 'Kredyt_inne', 'symbol': 'Kredyt_inne', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1197, 'name': 'Kredyt_dochod_emerytura', 'symbol': 'Kredyt_dochod_emerytura', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1198, 'name': 'Kredyt_dochod_zasilek', 'symbol': 'Kredyt_dochod_zasilek', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1029, 'name': 'Kredyt_wysokosc_kredytu', 'symbol': 'Kredyt_wysokosc_kredytu', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1030, 'name': 'Kredyt_dochod', 'symbol': 'Kredyt_dochod', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 954, 'name': 'Kredyt_nr_telefonu', 'symbol': 'Kredyt_nr_telefonu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1032, 'name': 'Kredyt_zgodnosc_informacji', 'symbol': 'Kredyt_zgodnosc_informacji', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1033, 'name': 'Kredyt_regulamin', 'symbol': 'Kredyt_regulamin', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1034, 'name': 'Kredyt_odpowiedzialnosc_karna', 'symbol': 'Kredyt_odpowiedzialnosc_karna', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1098, 'name': 'Kredyt_wysokosc_pozyczki', 'symbol': 'Kredyt_wysokosc_pozyczki', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1099, 'name': 'Kredyt_ilosc_rat', 'symbol': 'Kredyt_ilosc_rat', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1017, 'name': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'symbol': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1018, 'name': 'Kredyt_nazwa_firmy', 'symbol': 'Kredyt_nazwa_firmy', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1019, 'name': 'Kredyt_NIP_REGON', 'symbol': 'Kredyt_NIP_REGON', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1027, 'name': 'Kredyt_inne_string', 'symbol': 'Kredyt_inne_string', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1028, 'name': 'Kredyt_nazwa_banku', 'symbol': 'Kredyt_nazwa_banku', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1051, 'name': 'Kredyt_marketnig_elektroniczna', 'symbol': 'Kredyt_marketnig_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1031, 'name': 'Kredyt_rodzaj_zasilku', 'symbol': 'Kredyt_rodzaj_zasilku', 'unitId': 58}], 'screens': [{'id': 1536, 'name': 'Ekran_5_Zrodla_dochodow', 'symbol': 'Ekran_5_Zrodla_dochodow'}, {'id': 1534, 'name': 'Ekran_2_Dane_osobowe', 'symbol': 'Ekran_2_Dane_osobowe'}, {'id': 1537, 'name': 'Ekran_6_Podziekowanie', 'symbol': 'Ekran_6_Podziekowanie'}, {'id': 1539, 'name': 'Tech_BottomScreen', 'symbol': 'Tech_BottomScreen'}, {'id': 1540, 'name': 'Tech_TabsScreen', 'symbol': 'Tech_TabsScreen'}, {'id': 1541, 'name': 'Tech_TopScreen', 'symbol': 'Tech_TopScreen'}, {'id': 1535, 'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'symbol': 'Ekran_3_zrodla_wysokosc_dochodow'}, {'id': 1538, 'name': 'Ekran_65_Decyzja_konsultanta', 'symbol': 'Ekran_65_Decyzja_konsultanta'}, {'id': 1533, 'name': 'Ekran_1_ekran_Startowy', 'symbol': 'Ekran_1_ekran_Startowy'}], 'tasks': [{'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'sqif0GojUKI', 'name': 'InitialEvent0', 'relations': [{'id': 'arrow_mUsp4nJXu', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowInitialEvent'}, {'actionsList': [{'actionId': '2N8KxRhMBg2', 'actionType': 'StateIn', 'name': 'InUserTask0', 'symbol': 'InUserTask0'}, {'actionId': 'fZcUQQFoWId', 'actionType': 'StateOut', 'name': 'OutUserTask0', 'symbol': 'OutUserTask0'}, {'actionId': 'ejXwc6mkJN', 'actionType': 'Standard', 'name': 'a010_zoz_wniosek_online', 'symbol': 'a010_zoz_wniosek_online'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'A92RfIeeD1H', 'name': 'ut010_Startowy', 'relations': [{'id': 'arrow_tAzCWAAES', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': True}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '3HnTqJga3Hp', 'actionType': 'StateIn', 'name': 'InUserTask0_0', 'symbol': 'InUserTask0_0'}, {'actionId': 'HfMZAvsAUNp', 'actionType': 'StateOut', 'name': 'OutUserTask0_0', 'symbol': 'OutUserTask0_0'}, {'actionId': 'dIETSsy8l5', 'actionType': 'Standard', 'name': 'a020_Wstecz', 'symbol': 'a020_Wstecz'}, {'actionId': '72lLoVteTv', 'actionType': 'Standard', 'name': 'a020_dalej', 'symbol': 'a020_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'qcWPy4tnq2D', 'name': 'ut_020_dane_wnioskodawcy', 'relations': [{'id': 'arrow_suZAGAEA2', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}, {'id': 'arrow_nXLqve8W2', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}, {'id': 'arrow_lSglFqJe2', 'targetId': None, 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': True}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'QGjAWamgD2X', 'actionType': 'StateIn', 'name': 'InUserTask0_1', 'symbol': 'InUserTask0_1'}, {'actionId': 'zT40C4LdjOU', 'actionType': 'StateOut', 'name': 'OutUserTask0_1', 'symbol': 'OutUserTask0_1'}, {'actionId': 'RAOR4dDMMk', 'actionType': 'Standard', 'name': 'a030_wstecz', 'symbol': 'a030_wstecz'}, {'actionId': 'i1dWMSlwsk', 'actionType': 'Standard', 'name': 'a030_dalej', 'symbol': 'a030_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'nlNJf9NHp6g', 'name': 'ut030_parametry_pozyczki', 'relations': [{'id': 'arrow_7uBa0srSU', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}, {'id': 'arrow_AjiPAlS3s', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_kxEkdmBae', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_aGADHKzzZ', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': True}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '5wAt6CQ8fVq', 'actionType': 'StateIn', 'name': 'InUserTask0_3', 'symbol': 'InUserTask0_3'}, {'actionId': 'm1Rxxtf0KmN', 'actionType': 'StateOut', 'name': 'OutUserTask0_3', 'symbol': 'OutUserTask0_3'}, {'actionId': 'rrLBc2Na8b', 'actionType': 'Standard', 'name': 'a050_WyslijDoWeryfikacji', 'symbol': 'a050_WyslijDoWeryfikacji'}, {'actionId': 'iKXc6zh65G', 'actionType': 'Standard', 'name': 'a050_wstecz', 'symbol': 'a050_wstecz'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'Ec8tA2KQFEB', 'name': 'ut050_Zrodla_dochodow', 'relations': [{'id': 'arrow_zuREiTB7Z', 'targetId': 'D9AjaaZA8gg', 'type': 'Arrow'}, {'id': 'arrow_AnCASNgkH', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': True}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'Qb5Fr2OTEBl', 'actionType': 'StateIn', 'name': 'InUserTask0_4', 'symbol': 'InUserTask0_4'}, {'actionId': 'I4EH9EdmEej', 'actionType': 'StateOut', 'name': 'OutUserTask0_4', 'symbol': 'OutUserTask0_4'}, {'actionId': 'De1AOtYCJo', 'actionType': 'Standard', 'name': 'Zaakceptuj', 'symbol': 'a060_Akceptacja'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'D9AjaaZA8gg', 'name': 'ut060_decyzja_konsultanta', 'relations': [{'id': 'arrow_tz3xv7yhA', 'targetId': 'pxzdcS8iM03', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': True}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': True}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': True}], 'type': 'FlowUserTask'}, {'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'pxzdcS8iM03', 'name': 'ee060_akceptacjaWnioskuKredyt', 'relations': [], 'screenConfiguration': [], 'type': 'FlowEndEvent'}], 'location': 'https://uamedu.domdata.com/architect/bpmnDesigner'}

# %%
print(parse_context_json_v2(dict4))
# Out:
# PF.Kredyt_RODO_komunikat: String
# PF.Kredyt_zgody_koncowe: String
# PF.Kredyt_Imie_Klienta: String
# PF.Kredyt_Nazwisko: String
# PF.Kredyt_waznosc_dowodu: String
# PF.Kredyt_nr_dowodu: String
# PF.Kredyt_Pesel: String
# PF.Kredyt_e_mail: String
# PF.Kredyt_Data_urodzenia: String
# PF.Kredyt_data_wydania_dowodu: String
# PF.Kredyt_RODO: Bool
# PF.Kredyt_Komunikat_RODO: String
# PF.Kredyt_wynagrodzenie_za_prace: Bool
# PF.Kredyt_branza: String
# PF.Kredyt_zawod: String
# PF.Kredyt_czym_zajmuje_sie_firma: String
# PF.Kredyt_bilans_finansowy: Int
# PF.Kredyt_emerytura_renta: Bool
# PF.Kredyt_dochod_malzonka: Bool
# PF.Kredyt_dochod_wynagrodzenie: Decimal
# PF.Kredyt_alimenty: Bool
# PF.Kredyt_dochod_prowadzenie_dzialalnosci: Decimal
# PF.Kredyt_Info_Admi: Bool
# PF.Kredyt_marketing_tel: Bool
# PF.Kredyt_data_waznosci: DateTime
# PF.Kredyt_zasilki_spoleczne_socjalne: Bool
# PF.Kredyt_pozyczka: Bool
# PF.Kredyt_reg_drog_elektroniczna: Bool
# PF.Kredyt_datawydania: DateTime
# ...

# %%
dict5 = {'fields': [{'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1215, 'name': 'Kredyt_RODO_komunikat', 'symbol': 'Kredyt_RODO_komunikat', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1218, 'name': 'Kredyt_zgody_koncowe', 'symbol': 'Kredyt_zgody_koncowe', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 949, 'name': 'Kredyt_Imie_Klienta', 'symbol': 'Kredyt_Imie_Klienta', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 950, 'name': 'Kredyt_Nazwisko', 'symbol': 'Kredyt_Nazwisko', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 951, 'name': 'Kredyt_waznosc_dowodu', 'symbol': 'Kredyt_waznosc_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 952, 'name': 'Kredyt_nr_dowodu', 'symbol': 'Kredyt_nr_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 953, 'name': 'Kredyt_Pesel', 'symbol': 'Kredyt_Pesel', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 955, 'name': 'Kredyt_e_mail', 'symbol': 'Kredyt_e_mail', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 956, 'name': 'Kredyt_Data_urodzenia', 'symbol': 'Kredyt_Data_urodzenia', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 957, 'name': 'Kredyt_data_wydania_dowodu', 'symbol': 'Kredyt_data_wydania_dowodu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 958, 'name': 'Kredyt_RODO', 'symbol': 'Kredyt_RODO', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 959, 'name': 'Kredyt_Komunikat_RODO', 'symbol': 'Kredyt_Komunikat_RODO', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1014, 'name': 'Kredyt_wynagrodzenie_za_prace', 'symbol': 'Kredyt_wynagrodzenie_za_prace', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1015, 'name': 'Kredyt_branza', 'symbol': 'Kredyt_branza', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1016, 'name': 'Kredyt_zawod', 'symbol': 'Kredyt_zawod', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1020, 'name': 'Kredyt_czym_zajmuje_sie_firma', 'symbol': 'Kredyt_czym_zajmuje_sie_firma', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1193, 'name': 'Kredyt_bilans_finansowy', 'symbol': 'Kredyt_bilans_finansowy', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1021, 'name': 'Kredyt_emerytura_renta', 'symbol': 'Kredyt_emerytura_renta', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1022, 'name': 'Kredyt_dochod_malzonka', 'symbol': 'Kredyt_dochod_malzonka', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1194, 'name': 'Kredyt_dochod_wynagrodzenie', 'symbol': 'Kredyt_dochod_wynagrodzenie', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1023, 'name': 'Kredyt_alimenty', 'symbol': 'Kredyt_alimenty', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1195, 'name': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'symbol': 'Kredyt_dochod_prowadzenie_dzialalnosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1048, 'name': 'Kredyt_Info_Admi', 'symbol': 'Kredyt_Info_Admi', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1050, 'name': 'Kredyt_marketing_tel', 'symbol': 'Kredyt_marketing_tel', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1053, 'name': 'Kredyt_data_waznosci', 'symbol': 'Kredyt_data_waznosci', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1024, 'name': 'Kredyt_zasilki_spoleczne_socjalne', 'symbol': 'Kredyt_zasilki_spoleczne_socjalne', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1025, 'name': 'Kredyt_pozyczka', 'symbol': 'Kredyt_pozyczka', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1049, 'name': 'Kredyt_reg_drog_elektroniczna', 'symbol': 'Kredyt_reg_drog_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'DateTime', 'dataTypeComponents': [], 'domainId': 14, 'id': 1054, 'name': 'Kredyt_datawydania', 'symbol': 'Kredyt_datawydania', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1196, 'name': 'Kredyt_dochod_malzonk', 'symbol': 'Kredyt_dochod_malzonk', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1026, 'name': 'Kredyt_inne', 'symbol': 'Kredyt_inne', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1197, 'name': 'Kredyt_dochod_emerytura', 'symbol': 'Kredyt_dochod_emerytura', 'unitId': 58}, {'children': [], 'dataType': 'Decimal', 'dataTypeComponents': [], 'domainId': 14, 'id': 1198, 'name': 'Kredyt_dochod_zasilek', 'symbol': 'Kredyt_dochod_zasilek', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1029, 'name': 'Kredyt_wysokosc_kredytu', 'symbol': 'Kredyt_wysokosc_kredytu', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1030, 'name': 'Kredyt_dochod', 'symbol': 'Kredyt_dochod', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 954, 'name': 'Kredyt_nr_telefonu', 'symbol': 'Kredyt_nr_telefonu', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1032, 'name': 'Kredyt_zgodnosc_informacji', 'symbol': 'Kredyt_zgodnosc_informacji', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1033, 'name': 'Kredyt_regulamin', 'symbol': 'Kredyt_regulamin', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1034, 'name': 'Kredyt_odpowiedzialnosc_karna', 'symbol': 'Kredyt_odpowiedzialnosc_karna', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1098, 'name': 'Kredyt_wysokosc_pozyczki', 'symbol': 'Kredyt_wysokosc_pozyczki', 'unitId': 58}, {'children': [], 'dataType': 'Int', 'dataTypeComponents': [], 'domainId': 14, 'id': 1099, 'name': 'Kredyt_ilosc_rat', 'symbol': 'Kredyt_ilosc_rat', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1017, 'name': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'symbol': 'Kredyt_prowadzenie_dzialalnosci_gospodarczej', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1018, 'name': 'Kredyt_nazwa_firmy', 'symbol': 'Kredyt_nazwa_firmy', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1019, 'name': 'Kredyt_NIP_REGON', 'symbol': 'Kredyt_NIP_REGON', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1027, 'name': 'Kredyt_inne_string', 'symbol': 'Kredyt_inne_string', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1028, 'name': 'Kredyt_nazwa_banku', 'symbol': 'Kredyt_nazwa_banku', 'unitId': 58}, {'children': [], 'dataType': 'Bool', 'dataTypeComponents': [], 'domainId': 14, 'id': 1051, 'name': 'Kredyt_marketnig_elektroniczna', 'symbol': 'Kredyt_marketnig_elektroniczna', 'unitId': 58}, {'children': [], 'dataType': 'String', 'dataTypeComponents': [], 'domainId': 14, 'id': 1031, 'name': 'Kredyt_rodzaj_zasilku', 'symbol': 'Kredyt_rodzaj_zasilku', 'unitId': 58}], 'screens': [{'id': 1536, 'name': 'Ekran_5_Zrodla_dochodow', 'symbol': 'Ekran_5_Zrodla_dochodow'}, {'id': 1534, 'name': 'Ekran_2_Dane_osobowe', 'symbol': 'Ekran_2_Dane_osobowe'}, {'id': 1537, 'name': 'Ekran_6_Podziekowanie', 'symbol': 'Ekran_6_Podziekowanie'}, {'id': 1539, 'name': 'Tech_BottomScreen', 'symbol': 'Tech_BottomScreen'}, {'id': 1540, 'name': 'Tech_TabsScreen', 'symbol': 'Tech_TabsScreen'}, {'id': 1541, 'name': 'Tech_TopScreen', 'symbol': 'Tech_TopScreen'}, {'id': 1535, 'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'symbol': 'Ekran_3_zrodla_wysokosc_dochodow'}, {'id': 1538, 'name': 'Ekran_65_Decyzja_konsultanta', 'symbol': 'Ekran_65_Decyzja_konsultanta'}, {'id': 1533, 'name': 'Ekran_1_ekran_Startowy', 'symbol': 'Ekran_1_ekran_Startowy'}], 'tasks': [{'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'sqif0GojUKI', 'name': 'InitialEvent0', 'relations': [{'id': 'arrow_mUsp4nJXu', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}], 'screenConfiguration': [], 'type': 'FlowInitialEvent'}, {'actionsList': [{'actionId': '2N8KxRhMBg2', 'actionType': 'StateIn', 'name': 'InUserTask0', 'symbol': 'InUserTask0'}, {'actionId': 'fZcUQQFoWId', 'actionType': 'StateOut', 'name': 'OutUserTask0', 'symbol': 'OutUserTask0'}, {'actionId': 'ejXwc6mkJN', 'actionType': 'Standard', 'name': 'a010_zoz_wniosek_online', 'symbol': 'a010_zoz_wniosek_online'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'A92RfIeeD1H', 'name': 'ut010_Startowy', 'relations': [{'id': 'arrow_tAzCWAAES', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': True}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '3HnTqJga3Hp', 'actionType': 'StateIn', 'name': 'InUserTask0_0', 'symbol': 'InUserTask0_0'}, {'actionId': 'HfMZAvsAUNp', 'actionType': 'StateOut', 'name': 'OutUserTask0_0', 'symbol': 'OutUserTask0_0'}, {'actionId': 'dIETSsy8l5', 'actionType': 'Standard', 'name': 'a020_Wstecz', 'symbol': 'a020_Wstecz'}, {'actionId': '72lLoVteTv', 'actionType': 'Standard', 'name': 'a020_dalej', 'symbol': 'a020_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'qcWPy4tnq2D', 'name': 'ut_020_dane_wnioskodawcy', 'relations': [{'id': 'arrow_suZAGAEA2', 'targetId': 'A92RfIeeD1H', 'type': 'Arrow'}, {'id': 'arrow_nXLqve8W2', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}, {'id': 'arrow_lSglFqJe2', 'targetId': None, 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': True}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'QGjAWamgD2X', 'actionType': 'StateIn', 'name': 'InUserTask0_1', 'symbol': 'InUserTask0_1'}, {'actionId': 'zT40C4LdjOU', 'actionType': 'StateOut', 'name': 'OutUserTask0_1', 'symbol': 'OutUserTask0_1'}, {'actionId': 'RAOR4dDMMk', 'actionType': 'Standard', 'name': 'a030_wstecz', 'symbol': 'a030_wstecz'}, {'actionId': 'i1dWMSlwsk', 'actionType': 'Standard', 'name': 'a030_dalej', 'symbol': 'a030_dalej'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'nlNJf9NHp6g', 'name': 'ut030_parametry_pozyczki', 'relations': [{'id': 'arrow_7uBa0srSU', 'targetId': 'qcWPy4tnq2D', 'type': 'Arrow'}, {'id': 'arrow_AjiPAlS3s', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_kxEkdmBae', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}, {'id': 'arrow_aGADHKzzZ', 'targetId': 'Ec8tA2KQFEB', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': True}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': '5wAt6CQ8fVq', 'actionType': 'StateIn', 'name': 'InUserTask0_3', 'symbol': 'InUserTask0_3'}, {'actionId': 'm1Rxxtf0KmN', 'actionType': 'StateOut', 'name': 'OutUserTask0_3', 'symbol': 'OutUserTask0_3'}, {'actionId': 'rrLBc2Na8b', 'actionType': 'Standard', 'name': 'a050_WyslijDoWeryfikacji', 'symbol': 'a050_WyslijDoWeryfikacji'}, {'actionId': 'iKXc6zh65G', 'actionType': 'Standard', 'name': 'a050_wstecz', 'symbol': 'a050_wstecz'}], 'enabled': True, 'fieldConfiguration': [{'editable': True, 'id': 'PF', 'required': None, 'requiredInRPZ': None, 'visible': None}], 'id': 'Ec8tA2KQFEB', 'name': 'ut050_Zrodla_dochodow', 'relations': [{'id': 'arrow_zuREiTB7Z', 'targetId': 'D9AjaaZA8gg', 'type': 'Arrow'}, {'id': 'arrow_AnCASNgkH', 'targetId': 'nlNJf9NHp6g', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': True}, {'name': 'Tech_BottomScreen', 'visible': False}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': False}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': False}], 'type': 'FlowUserTask'}, {'actionsList': [{'actionId': 'Qb5Fr2OTEBl', 'actionType': 'StateIn', 'name': 'InUserTask0_4', 'symbol': 'InUserTask0_4'}, {'actionId': 'I4EH9EdmEej', 'actionType': 'StateOut', 'name': 'OutUserTask0_4', 'symbol': 'OutUserTask0_4'}, {'actionId': 'De1AOtYCJo', 'actionType': 'Standard', 'name': 'Zaakceptuj', 'symbol': 'a060_Akceptacja'}], 'enabled': True, 'fieldConfiguration': [], 'id': 'D9AjaaZA8gg', 'name': 'ut060_decyzja_konsultanta', 'relations': [{'id': 'arrow_tz3xv7yhA', 'targetId': 'pxzdcS8iM03', 'type': 'Arrow'}], 'screenConfiguration': [{'name': 'Ekran_1_ekran_Startowy', 'visible': False}, {'name': 'Ekran_2_Dane_osobowe', 'visible': False}, {'name': 'Ekran_3_zrodla_wysokosc_dochodow', 'visible': False}, {'name': 'Ekran_5_Zrodla_dochodow', 'visible': False}, {'name': 'Tech_BottomScreen', 'visible': True}, {'name': 'Tech_TabsScreen', 'visible': False}, {'name': 'Tech_TopScreen', 'visible': False}, {'name': 'Ekran_6_Podziekowanie', 'visible': True}, {'name': 'Ekran_65_Decyzja_konsultanta', 'visible': True}], 'type': 'FlowUserTask'}, {'actionsList': [], 'enabled': True, 'fieldConfiguration': [], 'id': 'pxzdcS8iM03', 'name': 'ee060_akceptacjaWnioskuKredyt', 'relations': [], 'screenConfiguration': [], 'type': 'FlowEndEvent'}], 'location': 'https://uamedu.domdata.com/architect/bpmnDesigner'}

# %%
print(parse_context_json_v2(dict5))
# Out:
# PF.Kredyt_RODO_komunikat: String
# PF.Kredyt_zgody_koncowe: String
# PF.Kredyt_Imie_Klienta: String
# PF.Kredyt_Nazwisko: String
# PF.Kredyt_waznosc_dowodu: String
# PF.Kredyt_nr_dowodu: String
# PF.Kredyt_Pesel: String
# PF.Kredyt_e_mail: String
# PF.Kredyt_Data_urodzenia: String
# PF.Kredyt_data_wydania_dowodu: String
# PF.Kredyt_RODO: Bool
# PF.Kredyt_Komunikat_RODO: String
# PF.Kredyt_wynagrodzenie_za_prace: Bool
# PF.Kredyt_branza: String
# PF.Kredyt_zawod: String
# PF.Kredyt_czym_zajmuje_sie_firma: String
# PF.Kredyt_bilans_finansowy: Int
# PF.Kredyt_emerytura_renta: Bool
# PF.Kredyt_dochod_malzonka: Bool
# PF.Kredyt_dochod_wynagrodzenie: Decimal
# PF.Kredyt_alimenty: Bool
# PF.Kredyt_dochod_prowadzenie_dzialalnosci: Decimal
# PF.Kredyt_Info_Admi: Bool
# PF.Kredyt_marketing_tel: Bool
# PF.Kredyt_data_waznosci: DateTime
# PF.Kredyt_zasilki_spoleczne_socjalne: Bool
# PF.Kredyt_pozyczka: Bool
# PF.Kredyt_reg_drog_elektroniczna: Bool
# PF.Kredyt_datawydania: DateTime
# ...

# %%
gpt_generated = {
  "fields": [
    {
      "children": [
        {
          "maxCharacters": 20,
          "minCharacters": 2,
          "symbol": "ImieKlienta",
          "type": "Default"
        },
        {
          "maxCharacters": 20,
          "minCharacters": 2,
          "symbol": "NazwiskoKlienta",
          "type": "Default"
        },
        {
          "clientValidationId": 2,
          "symbol": "PESELKlienta",
          "type": "Default"
        },
        {
          "clientValidationId": 3,
          "symbol": "EmailKlienta",
          "type": "Default"
        },
        {
          "maxCharacters": 9,
          "minCharacters": 9,
          "symbol": "TelefonKlienta",
          "type": "Default"
        }
      ],
      "dataType": "Domena_APD_M.obszar_AngKor.DaneOsobowe_S",
      "dataTypeComponents": [
        {
          "name": "ImieKlienta",
          "symbol": "ImieKlienta",
          "type": "String"
        },
        {
          "name": "NazwiskoKlienta",
          "symbol": "NazwiskoKlienta",
          "type": "String"
        },
        {
          "name": "PESELKlienta",
          "symbol": "PESELKlienta",
          "type": "String"
        },
        {
          "name": "EmailKlienta",
          "symbol": "EmailKlienta",
          "type": "String"
        },
        {
          "name": "TelefonKlienta",
          "symbol": "TelefonKlienta",
          "type": "String"
        }
      ],
      "domainId": 5,
      "id": 606,
      "name": "ZPU_dane_osobowe",
      "symbol": "ZPU_dane_osobowe",
      "unitId": 25
    },
    {
      "children": [
        {
          "children": [
            {
              "dictionaryId": 21,
              "symbol": "Wojewodztwo",
              "type": "Default"
            },
            {
              "dictionaryId": 23,
              "symbol": "Typ_adresu",
              "type": "Default"
            }
          ],
          "symbol": "t.",
          "type": "Table"
        }
      ],
      "dataType": "Domena_APD_M.obszar_AngKor.DaneAdresowe_T",
      "dataTypeComponents": [],
      "domainId": 5,
      "id": 634,
      "name": "ZPU_DaneAdresowe",
      "symbol": "ZPU_DaneAdresowe",
      "unitId": 25
    },
    {
      "children": [],
      "dataType": "String",
      "dataTypeComponents": [],
      "domainId": 5,
      "id": 700,
      "name": "ZPU_RODO_komunikat",
      "symbol": "ZPU_RODO_komunikat",
      "unitId": 25
    },
    {
      "children": [],
      "dataType": "Bool",
      "dataTypeComponents": [],
      "domainId": 5,
      "id": 613,
      "name": "ZPU_RODO",
      "symbol": "ZPU_RODO",
      "unitId": 25
    },
    {
      "children": [],
      "dataType": "Bool",
      "dataTypeComponents": [],
      "domainId": 5,
      "id": 865,
      "name": "ZPU_czy_powyzej_35t",
      "symbol": "ZPU_czy_powyzej_35t",
      "unitId": 25
    },
    {
      "children": [],
      "dataType": "Bool",
      "dataTypeComponents": [],
      "domainId": 5,
      "id": 869,
      "name": "ZPU_czy_budowlany",
      "symbol": "ZPU_czy_budowlany",
      "unitId": 25
    }
  ],
  "screens": [
    {
      "id": 938,
      "name": "Ekran_1_Powitanie",
      "symbol": "Ekran_1_AngKor"
    },
    {
      "id": 935,
      "name": "Tech_TopScreen",
      "symbol": "Tech_TopScreen"
    },
    {
      "id": 936,
      "name": "Tech_BottomScreen",
      "symbol": "Tech_BottomScreen"
    },
    {
      "id": 937,
      "name": "Tech_TabsScreen",
      "symbol": "Tech_TabsScreen"
    },
    {
      "id": 939,
      "name": "Ekran_2_Zakres_ubezpieczenia",
      "symbol": "Ekran_2_AngKor"
    },
    {
      "id": 940,
      "name": "Ekran3_Dane_Osobowe",
      "symbol": "Ekran3_Ang_Kor"
    },
    {
      "id": 941,
      "name": "Ekran_4_Dane_adresowe",
      "symbol": "Ekran_4_Dane_adresowe"
    },
    {
      "id": 942,
      "name": "Ekran_5_Podsumowanie",
      "symbol": "Ekran_5_Podsumowanie"
    },
    {
      "id": 1021,
      "name": "Ekran15_TypPojazdu",
      "symbol": "Ekran15_TypPojazdu"
    },
    {
      "id": 1256,
      "name": "Ekran_65_Decyzja_Konsultanta",
      "symbol": "Ekran_65_Decyzja_Konsultanta"
    },
    {
      "id": 1252,
      "name": "Ekran_6_Podziękowanie",
      "symbol": "Ekran_6Podziekowanie"
    }
  ]
}

# %%
print(parse_context_json_v2(gpt_generated))
# Out:
# PF.DaneOsobowe_S.ImieKlienta: String
# PF.DaneOsobowe_S.NazwiskoKlienta: String
# PF.DaneOsobowe_S.PESELKlienta: String
# PF.DaneOsobowe_S.EmailKlienta: String
# PF.DaneOsobowe_S.TelefonKlienta: String
# PF.DaneAdresowe_T: Table
#   Wojewodztwo: Str
#   Typ_adresu: Str
# PF.ZPU_RODO_komunikat: String
# PF.ZPU_RODO: Bool
# PF.ZPU_czy_powyzej_35t: Bool
# PF.ZPU_czy_budowlany: Bool

# %%
def parse_context_json_v3(context: dict):
    """Approach 2: Checking if dataType contains dots."""
    
    fields_processed = []
    try:
        fields = context["fields"]
        for field in fields:
            if field["dataType"].count(".") == 0:
                fields_processed.append(f"PF.{field["symbol"]}: {field["dataType"]}")
            else:
                structure = field["dataType"].split(".")[-1]
                if not field["children"]:
                    if field["dataTypeComponents"]:
                        for component in field["dataTypeComponents"]:
                            fields_processed.append(f"PF.{structure}.{component['symbol']}: {component['type']}")
                    else:
                            fields_processed.append(f"PF.{structure}: Table")
                else:
                    if field["dataTypeComponents"]:
                        for component in field["dataTypeComponents"]:
                            fields_processed.append(f"PF.{structure}.{component['symbol']}: {component['type']}")
                    else:
                        fields_processed.append(f"PF.{structure}: Table")
                        for child in field["children"][0]["children"]:
                            fields_processed.append(f"  {child["symbol"]}: Str")
    
    except Exception as e:
        fields_processed.append(f"Data model not available due to error: {str(e)}. Ask user to provide data model.")
                    
    fields_processed_joined = "\n".join(fields_processed)
    
    
    return fields_processed_joined

# %%
print(parse_context_json_v3(presentation_str))
# Out:
# PF.UR_DaneKlienta_S.Imie: String
# PF.UR_DaneKlienta_S.Nazwisko: String
# PF.UR_DaneKlienta_S.Email: String
# PF.UR_DaneKlienta_S.NrTelefonu: String
# PF.UR_KodZnizkowy: String
# PF.UR_OdrzuceniePrzezWiek: Bool
# PF.UR_RodzajUbezpieczenia: String
# PF.UR_Skladka: Decimal
# PF.UR_DaneRodziny_T: Table
# PF.tech_Message: String
# PF.UR_PoziomUbezpieczenia: String
# PF.UR_UbezpieczenieDodatkowe: Bool

# %%
print(parse_context_json_v3("miau"))
# Out:
# Data model not available due to error: string indices must be integers, not 'str'. Ask user to provide data model.

# %%
print(parse_context_json_v3({ "children": [],
      "dataType": "Bool",
      "dataTypeComponents": [],
      "domainId": 14,
      "id": 1014,
      "name": "Kredyt_wynagrodzenie_za_prace",
      "symbol": "Kredyt_wynagrodzenie_za_prace",
      "unitId": 58}))
# Out:
# Data model not available due to error: 'fields'. Ask user to provide data model.

# %% [markdown]
# # Screens

# %%
def parse_context_screen(context: dict) -> str:
    """Parse screens from context."""
    
    screens_processed = []
    try:
        screens = context["screens"]
        for screen in screens:
            screens_processed.append(f"{screen["symbol"]} (alias:{screen['name']})")

    except Exception as e:
        screens_processed.append(f"Screens not available due to error: {str(e)}. Ask user to provide available screens.")
                    
    screens_processed_joined = "\n".join(screens_processed)
    
    
    return screens_processed_joined

# %%
print(parse_context_screen(presentation_str))
# Out:
# Tech_BottomScreen (alias:Tech_BottomScreen)
# Tech_TopScreen (alias:Tech_TopScreen)
# Tech_TabsScreen (alias:Tech_TabsScreen)
# Tech_SessionEndScreen (alias:Tech_SessionEndScreen)
# E040_Zgody (alias:Zgody)
# E020_DaneRodziny (alias:Dane rodziny)
# E050_Podsumowanie (alias:Podsumowanie)
# E030_WyborUbezpieczenia (alias:Wybór ubezpieczenia)
# E010_Powitanie (alias:Powitanie)
# E060_Odrzucenie (alias:Odrzucenie)
# E_techMessage (alias:E_techMessage)

# %%
print(parse_context_screen(json_string))
# Out:
# Ekran_1_AngKor (alias:Ekran_1_Powitanie)
# Tech_TopScreen (alias:Tech_TopScreen)
# Tech_BottomScreen (alias:Tech_BottomScreen)
# Tech_TabsScreen (alias:Tech_TabsScreen)
# Ekran_2_AngKor (alias:Ekran_2_Zakres_ubezpieczenia)
# Ekran3_Ang_Kor (alias:Ekran3_Dane_Osobowe)
# Ekran_4_Dane_adresowe (alias:Ekran_4_Dane_adresowe)
# Ekran_5_Podsumowanie (alias:Ekran_5_Podsumowanie)
# Ekran15_TypPojazdu (alias:Ekran15_TypPojazdu)
# Ekran_65_Decyzja_Konsultanta (alias:Ekran_65_Decyzja_Konsultanta)
# Ekran_6Podziekowanie (alias:Ekran_6_Podziękowanie)
